# %%
import torch


print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"CUDA Version: {torch.version.cuda}")
print(f"PyTorch Version: {torch.__version__}")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       4 print(f"GPU: {torch.cuda.get_device_name(0)}")
#       5 print(f"CUDA Version: {torch.version.cuda}")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\__init__.py:280
#     276                     raise err
#     278         kernel32.SetErrorMode(prev_error_mode)
# --> 280     _load_dll_libraries()
#     281     del _load_dll_libraries
#     284 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     285     # Libraries can either be in
#     286     # path/nvidia/lib_folder/lib or
#     287     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     288     # path/lib_folder/lib
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\__init__.py:263, in _load_dll_libraries()
#     259     err = ctypes.WinError(last_error)
# ...

# %%
import pandas as pd
data = pd.read_csv("archive/The Quran Dataset.csv")

print(data.head(7))
# Out:
#    surah_no surah_name_en surah_name_ar surah_name_roman  ayah_no_surah  \
# 0         1    The Opener       الفاتحة       Al-Fatihah              1
# 1         1    The Opener       الفاتحة       Al-Fatihah              2
# 2         1    The Opener       الفاتحة       Al-Fatihah              3
# 3         1    The Opener       الفاتحة       Al-Fatihah              4
# 4         1    The Opener       الفاتحة       Al-Fatihah              5
# 5         1    The Opener       الفاتحة       Al-Fatihah              6
# 6         1    The Opener       الفاتحة       Al-Fatihah              7
#
#    ayah_no_quran                                            ayah_ar  \
# 0              1             بِسْمِ ٱللَّهِ ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 1              2              ٱلْحَمْدُ لِلَّهِ رَبِّ ٱلْعَٰلَمِينَ
# 2              3                            ٱلرَّحْمَٰنِ ٱلرَّحِيمِ
# 3              4                            مَٰلِكِ يَوْمِ ٱلدِّينِ
# ...
